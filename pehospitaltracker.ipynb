# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('PE_Hospital_Tracker.csv')

# %%
grouped = df.groupby('Type').count()
grouped
# Out:
#                                     Name  Facility ID (CCN)  \
# Type
# Acute Care - Department of Defense    35                 35
# Acute Care Hospitals                3171               3171
# Childrens                             91                 91
# Critical Access Hospitals           1355               1355
# LTACH                                346                346
# Psychiatric                          612                613
# Rehabilitation hospital              310                310
# Religious non-med                     15                 15
#
#                                     Parent System/Company  PE Firm  \
# Type
# Acute Care - Department of Defense                      0        0
# Acute Care Hospitals                                  680      192
# Childrens                                              10        0
# Critical Access Hospitals                              62       19
# LTACH                                                 313       78
# ...

# %% [markdown]
# Note: There are 613 facility IDs for psychiatric hospitals but only 612 names. This is because the address provided for that entry leads to Montevista Hospital in Las Vegas, which was shuttered in 2019 by federal regulators after facing hundreds of health and safety complaints. It has reopened as of 2021 as Desert Winds Hospital in the same location.
